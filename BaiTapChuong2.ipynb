# %% [markdown]
# <a href="https://colab.research.google.com/github/DTH235737-LeNgocMinhPhuc/DTH235737_LeNgocMinhPhuc_NOPBAI/blob/main/BaiTapChuong2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Câu 1
import math
try:
 r=float(input("Mời bạn nhập bán kính hình tròn:"))
 cv=2*math.pi*r
 dt=r**2
 print("Chu vi =",cv)
 print("Diện tích=",dt)
except:
 print("Lỗi rồi!")
# Out:
# Mời bạn nhập bán kính hình tròn:4
# Chu vi = 25.132741228718345
# Diện tích= 16.0

# %%
#Câu 2
t=int(input("Nhập số giây:"))
hour=(t//3600)%24
minute=(t%3600)//60
second=(t%3600)%60
print(hour,":",minute,":",second)
# Out:
# Nhập số giây:846000
# 19 : 0 : 0

# %%
#Câu 3
toan=float(input("Nhập điểm Toán:"))
ly=float(input("Nhập điểm lý:"))
hoa=float(input("Nhập điểm hóa:"))
dtb=(toan+ly+hoa)/3
print("Điểm trung bình=",dtb)
print("Điểm trung bình=",round(dtb,2))
# Out:
# Nhập điểm Toán:0
# Nhập điểm lý:8
# Nhập điểm hóa:9
# Điểm trung bình= 5.666666666666667
# Điểm trung bình= 5.67

# %%
#Câu 4: Python hỗ trợ những kiểu dữ liệu cơ bản nào?
# Kiểu số: interger, float, complex
# Kiểu chuỗi (string)

# %%
""" Câu 5: các loại ghi chú trong python
dấu #: chú thích trong 1 dòng
dấu 3 nháy: có thể xuống dòng được
thường các chú thích này để cho người đọc code và người làm ra code có thể theo
dõi để biết được phần code đó thuộc về cái gì"""

# %%
#Câu 6:
# / là phép chia thông thường, // là chia lấy nguyên, % chia lấy dư
# ** lũy thừa
# and: Là toán tử logic nhị phân (thao tác trên hai toán hạng), trả về True chỉ khi cả hai toán hạng đều là True. Ví dụ: True and False sẽ trả về False.
# or: Là toán tử logic nhị phân, trả về True nếu ít nhất một trong hai toán hạng là True. Ví dụ: True or False sẽ trả về True.
# is: Được sử dụng để kiểm tra xem hai biến có trỏ đến cùng một đối tượng trong bộ nhớ hay không, chứ không chỉ kiểm tra xem chúng có cùng giá trị hay không.

# %%
#Câu 7:Trình bày một số cách nhập dữ liệu từ bàn phím
# xài lệnh input, vd nhap = input("Nhập 1 cái gì đó "), còn nếu muốn kiểu dữ liệu khác thì có thể để kiểu dữ liệu trước input
# vd: so= int(input("Nhập 1 số nào đó "))
nhap = input("Nhập 1 cái gì đó ")
so= int(input("Nhập 1 số nào đó "))
print("Thứ bạn vừa nhập là: ", nhap)
print("Số bạn vừa nhập: ", so)
# Out:
# Nhập 1 cái gì đó abc
# Nhập 1 số nào đó 4
# Thứ bạn vừa nhập là:  abc
# Số bạn vừa nhập:  4

# %%
#Câu 8: Trình bày các loại lỗi khi lập trình và cách bắt lỗi trong Python
'''
Lỗi cú pháp (SyntaxError)
Mô tả: Lỗi xảy ra khi mã của bạn không tuân thủ đúng các quy tắc ngữ pháp của Python. Trình thông dịch Python không thể hiểu và biên dịch mã này.

Lỗi thực thi (Runtime Errors / Exceptions)
Mô tả: Lỗi này xảy ra trong quá trình chương trình đang chạy, khi một điều kiện bất thường xuất hiện và gây ra lỗi.

Lỗi logic (Logic Errors / Semantic Errors)
Mô tả: Lỗi này là loại khó tìm nhất vì chương trình chạy và không bị sập, nhưng lại cho ra kết quả sai hoặc không như mong đợi.
'''

# %%
#Câu 9: Giải thích kết quả tính toán của các biểu thức
'''
i1 = 2
i2 = 5
i3 = -3
d1 = 2.0
d2 = 5.0
d3 = -0.5

(a) i1 + (i2 * i3)
=2 + (5* - 3)
= -13

(b) i1 * (i2 + i3)
= 2 * (5 + -3)
= 2 * 2
= 4

(c) i1 / (i2 + i3)
= 2 / (5 + -3)
= 2 / 2
= 1

(d) i1 // (i2 + i3)
= 2 // (5 + -3)
= 2 // 2
= 1.0

(e) i1 / i2 + i3
= 2/5 + -3
= -2.6

(f) i1 // i2 + i3
= 2//5 + -3
= -3

(g) 3 + 4 + 5 / 3
= 3 + 4 + 1.6666666666666667
= 8.666666666666667

(h) 3 + 4 + 5 // 3
= 3 + 4 + 1
= 8

(i) (3 + 4 + 5) / 3
= 12 / 3
= 4.0

(j) (3 + 4 + 5) // 3
= 12 // 3
= 4

(k) d1 + (d2 * d3)
= 2.0 + (5.0 * -0.5)
= 2.0 + -2.5
= -0.5

(l) d1 + d2 * d3
= 2.0 + (5.0 * -0.5)
= 2.0 + -2.5
= -0.5

(m) d1 / d2 - d3
= (2.0 / 5.0) - (-0.5)
= 0.4 + 0.5 = 0.9

(n) d1 / (d2 - d3)
= 2.0 / (5.0 - -0.5)
= 2.0 / 5.5
= 0,3636

(o) d1 + d2 + d3 / 3
= = 2.0 + 5.0 + (-0.5 / 3)
= 7.0 - 0.166
= 6.833

(p) (d1 + d2 + d3) / 3
= (2.0 + 5.0 + -0.5) / 3
= 6.5 / 3
= 2.166

(q) d1 + d2 + (d3 / 3)
= 2.0 + 5.0 + (-0.5 / 3)
= 7.0 - 0.166
= 6.833

(r) 3 * (d1 + d2) * (d1 - d3)
= 3 * (2.0 + 5.0) * (2.0 - (-0.5))
= 3 * 7.0 * 2.5
= 21 * 2.5
= 52.5
'''

# %%
#Câu 10: Hãy viết ngắn gọn lại các lệnh dưới đây
'''
(a) x = x + 1
-> x += 1

(b) x = x / 2
-> x /= 2

(c) x = x – 1
-> x -= 1

(d) x = x + y
-> x += y

(e) x = x - (y + 7)
-> x -= y + 7

(f) x = 2*x
-> x *= 2

(g) number_of_closed_cases = number_of_closed_cases + 2*ncc
-> number_of_closed_cases += 2*ncc
'''
